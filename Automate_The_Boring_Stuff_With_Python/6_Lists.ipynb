# %% [markdown]
# ## Lists

# %%
spam = ['cat', 'bat', 'rat', 'elephant']
spam[0:3]
# Out:
# ['cat', 'bat', 'rat']

# %%
spam[1] = 'aardvark'
spam
# Out:
# ['cat', 'aardvark', 'rat', 'elephant']

# %% [markdown]
# String methods are functions that can be applied to strings
#
# Can access via a string.method()

# %%
tuple = ('cat', 'bat', 'rat', 'elephant')
tuple[0:3]
# Out:
# ('cat', 'bat', 'rat')

# %% [markdown]
# ## Tuples
#
# Tuples are like lists except they are:
# - Using () instead of []
# - Immutable

# %%
tuple[1] = 'aardvark'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 tuple[1] = 'aardvark'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Variables
#
# Variables are paper name tags attached to values with string
#
# ![image.png](attachment:image.png)

# %%
spam = 42
eggs = spam
spam = 100
print(spam)
print(eggs)
# Out:
# 100
# 42
